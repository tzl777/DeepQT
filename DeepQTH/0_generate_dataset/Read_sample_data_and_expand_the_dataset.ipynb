# %% [markdown]
# ### Step 0
# #### First, perform the DFT molecular dynamics calculation on the samples in &zwnj;**sample_data**&zwnj;, ensuring that the molecular dynamics trajectory file &zwnj;***SystemLabel.ANI***&zwnj; is obtained. This file stores the geometric structure evolution of the system at each time step.

# %%
import os
import sys
import numpy as np

# %%
# Read the *.ANI file
def read_ani_file(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()
    structures = []
    step_lines = []
    for line in lines:
        if line.strip().isdigit() and step_lines:
            stru_coords = [line.split() for line in step_lines[2:]]
            for i in range(len(stru_coords)):
                if stru_coords[i][0] == "C":
                    atom_species = 1
                # elif stru_coords[i][0] == "N":
                #     atom_species = 2
                else:
                    atom_species = 0
                stru_coords[i].append(int(atom_species))
            structures.append(np.array([x[1:] for x in stru_coords]))
            step_lines = []
        step_lines.append(line)

    if step_lines:
        stru_coords = [line.split() for line in step_lines[2:]]
        for i in range(len(stru_coords)):
            if stru_coords[i][0] == "C":
                atom_species = 1
            # elif stru_coords[i][0] == "N":
            #     atom_species = 2
            else:
                atom_species = 0
            stru_coords[i].append(int(atom_species))
        structures.append(np.array([x[1:] for x in stru_coords]))

    return structures

# %%
# Save the individual molecular dynamics trajectory to the input file of siesta
import re
def write_structure_to_folder(structure, fdf_file, foldername):
    if not os.path.exists(foldername):
        os.makedirs(foldername)

    filename = os.path.join(foldername, 'input.fdf')
    coords_str = ''
    for i in range(len(structure)):
        coords_str += f'{structure[i, 0]} {structure[i, 1]} {structure[i, 2]} {structure[i, 3]}'
        if i != len(structure) - 1:
            coords_str += '\n'

    with open(fdf_file, 'r') as f:
        content = f.read()

    pattern = r'%block\s+AtomicCoordinatesAndAtomicSpecies\s*\n(.*?)\n%endblock\s+AtomicCoordinatesAndAtomicSpecies'

    new_content = re.sub(pattern, 
                        f'%block AtomicCoordinatesAndAtomicSpecies\n{coords_str}\n%endblock AtomicCoordinatesAndAtomicSpecies',
                        content,
                        flags=re.DOTALL)  # 使.匹配换行符

    pattern = r'(MD\.FinalTimeStep\s+)\d+'
    content = re.sub(pattern, r'\g<1>1', new_content)

    insert_pos = content.find('MD.FinalTimeStep')
    if insert_pos != -1:
        line_end = content.find('\n', insert_pos) + 1
        final_content = content[:line_end] + 'MD.Steps             0\n' + content[line_end:]

    os.makedirs(foldername, exist_ok=True)
    with open(filename, 'w') as f:
        f.write(final_content)

# %%
#Read the molecular dynamics trajectories and save them to the extend_dataset

ani_filename = './sample_data/0/graphene72.ANI'
output_base_folder = './expand_dataset/raw/'
fdf_file = './sample_data/0/input.fdf'

structures = read_ani_file(ani_filename)[400:] # Select the structure of the last 600 time steps as the dataset
print(f"Select the structure of the last {len(structures)} time steps as the dataset.")

for step, structure in enumerate(structures):
    foldername = os.path.join(output_base_folder, f'{step+1}')
    #print(foldername)
    write_structure_to_folder(structure, fdf_file, foldername)
# Out:
# Select the structure of the last 600 time steps as the dataset.

# %%
import os
import shutil
from pathlib import Path

def batch_copy_files(src_dir, dst_base, file_patterns, num_range):

    src_path = Path(src_dir)
    dst_base = Path(dst_base)
    
    # 验证源目录存在
    if not src_path.exists():
        raise FileNotFoundError(f"The source directory does not exist: {src_path}")
    
    # 创建目标目录结构
    dst_base.mkdir(parents=True, exist_ok=True)
    
    # 收集源文件
    src_files = []
    for pattern in file_patterns:
        src_files.extend(src_path.glob(pattern))
    print(src_files)
    if not src_files:
        print("Warning: No matching source file was found!")
        return
    
    for i in num_range:
        target_dir = dst_base / str(i)
        target_dir.mkdir(exist_ok=True)
        
        for src_file in src_files:
            shutil.copy2(src_file, target_dir)
            print(f"Copy: {src_file} -> {target_dir/ src_file.name}")

if __name__ == "__main__":

    ani_filename = './sample_data/0/'
    output_base_folder = './expand_dataset/raw'
    file_patterns = ['*.psf', '*.sh']

    batch_copy_files(
        src_dir=ani_filename,
        dst_base=output_base_folder,
        file_patterns=file_patterns,
        num_range=range(1, 601)
    )
# Out:
# [PosixPath('sample_data/0/C.psf'), PosixPath('sample_data/0/job.sh')]
# Copy: sample_data/0/C.psf -> expand_dataset/raw/1/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/1/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/2/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/2/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/3/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/3/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/4/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/4/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/5/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/5/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/6/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/6/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/7/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/7/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/8/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/8/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/9/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/9/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/10/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/10/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/11/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/11/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/12/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/12/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/13/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/13/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/14/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/14/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/15/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/15/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/16/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/16/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/17/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/17/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/18/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/18/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/19/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/19/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/20/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/20/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/21/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/21/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/22/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/22/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/23/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/23/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/24/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/24/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/25/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/25/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/26/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/26/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/27/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/27/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/28/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/28/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/29/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/29/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/30/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/30/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/31/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/31/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/32/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/32/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/33/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/33/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/34/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/34/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/35/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/35/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/36/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/36/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/37/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/37/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/38/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/38/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/39/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/39/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/40/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/40/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/41/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/41/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/42/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/42/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/43/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/43/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/44/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/44/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/45/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/45/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/46/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/46/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/47/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/47/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/48/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/48/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/49/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/49/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/50/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/50/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/51/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/51/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/52/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/52/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/53/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/53/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/54/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/54/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/55/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/55/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/56/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/56/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/57/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/57/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/58/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/58/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/59/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/59/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/60/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/60/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/61/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/61/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/62/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/62/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/63/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/63/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/64/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/64/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/65/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/65/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/66/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/66/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/67/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/67/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/68/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/68/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/69/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/69/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/70/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/70/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/71/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/71/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/72/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/72/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/73/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/73/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/74/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/74/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/75/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/75/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/76/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/76/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/77/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/77/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/78/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/78/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/79/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/79/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/80/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/80/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/81/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/81/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/82/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/82/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/83/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/83/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/84/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/84/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/85/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/85/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/86/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/86/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/87/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/87/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/88/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/88/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/89/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/89/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/90/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/90/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/91/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/91/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/92/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/92/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/93/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/93/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/94/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/94/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/95/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/95/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/96/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/96/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/97/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/97/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/98/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/98/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/99/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/99/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/100/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/100/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/101/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/101/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/102/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/102/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/103/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/103/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/104/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/104/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/105/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/105/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/106/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/106/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/107/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/107/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/108/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/108/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/109/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/109/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/110/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/110/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/111/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/111/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/112/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/112/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/113/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/113/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/114/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/114/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/115/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/115/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/116/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/116/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/117/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/117/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/118/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/118/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/119/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/119/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/120/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/120/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/121/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/121/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/122/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/122/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/123/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/123/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/124/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/124/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/125/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/125/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/126/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/126/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/127/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/127/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/128/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/128/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/129/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/129/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/130/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/130/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/131/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/131/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/132/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/132/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/133/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/133/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/134/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/134/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/135/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/135/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/136/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/136/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/137/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/137/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/138/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/138/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/139/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/139/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/140/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/140/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/141/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/141/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/142/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/142/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/143/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/143/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/144/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/144/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/145/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/145/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/146/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/146/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/147/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/147/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/148/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/148/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/149/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/149/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw
C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/599/job.sh
# Copy: sample_data/0/C.psf -> expand_dataset/raw/600/C.psf
# Copy: sample_data/0/job.sh -> expand_dataset/raw/600/job.sh

# %%
# Submit all the data to the supercomputer for DFT calculations.
# num1 -> num2, Submit in batches, with 100 jobs in each batch.

save_str = """#!/bin/bash
num1=501
num2=600

if [ $num1 -gt $num2 ]; then
  echo "The first number must be less than or equal to the second number."
  exit 1
fi

for ((i = num1; i <= num2; i++))
do

cd ./expand_dataset/raw/$i
yhbatch job.sh
cd ../../../
done
    """
with open('./run_dft.sh', 'w') as save_f:
    save_f.write(save_str)

import subprocess
 
cmd = f"sh ./run_dft.sh"     
subprocess.run(cmd, shell=True)
# Out:
# Submitted batch job 7507213
# Submitted batch job 7507214
# Submitted batch job 7507215
# Submitted batch job 7507216
# Submitted batch job 7507217
# Submitted batch job 7507218
# Submitted batch job 7507219
# Submitted batch job 7507220
# Submitted batch job 7507221
# Submitted batch job 7507222
# Submitted batch job 7507223
# Submitted batch job 7507224
# Submitted batch job 7507225
# Submitted batch job 7507226
# Submitted batch job 7507227
# Submitted batch job 7507228
# Submitted batch job 7507229
# Submitted batch job 7507230
# Submitted batch job 7507231
# Submitted batch job 7507232
# Submitted batch job 7507233
# Submitted batch job 7507234
# Submitted batch job 7507235
# Submitted batch job 7507236
# Submitted batch job 7507237
# Submitted batch job 7507238
# Submitted batch job 7507239
# Submitted batch job 7507240
# Submitted batch job 7507241
# Submitted batch job 7507242
# Submitted batch job 7507243
# Submitted batch job 7507244
# Submitted batch job 7507245
# Submitted batch job 7507246
# Submitted batch job 7507247
# Submitted batch job 7507248
# Submitted batch job 7507249
# Submitted batch job 7507250
# Submitted batch job 7507251
# Submitted batch job 7507252
# Submitted batch job 7507253
# Submitted batch job 7507254
# Submitted batch job 7507255
# Submitted batch job 7507256
# Submitted batch job 7507257
# Submitted batch job 7507258
# Submitted batch job 7507259
# Submitted batch job 7507260
# Submitted batch job 7507261
# Submitted batch job 7507262
# Submitted batch job 7507263
# Submitted batch job 7507264
# Submitted batch job 7507265
# Submitted batch job 7507266
# Submitted batch job 7507267
# Submitted batch job 7507268
# Submitted batch job 7507269
# Submitted batch job 7507270
# Submitted batch job 7507271
# Submitted batch job 7507272
# Submitted batch job 7507273
# Submitted batch job 7507274
# Submitted batch job 7507275
# Submitted batch job 7507276
# Submitted batch job 7507277
# Submitted batch job 7507278
# Submitted batch job 7507279
# Submitted batch job 7507280
# Submitted batch job 7507281
# Submitted batch job 7507282
# Submitted batch job 7507283
# Submitted batch job 7507284
# Submitted batch job 7507285
# Submitted batch job 7507286
# Submitted batch job 7507287
# Submitted batch job 7507288
# Submitted batch job 7507289
# Submitted batch job 7507290
# Submitted batch job 7507291
# Submitted batch job 7507293
# Submitted batch job 7507294
# Submitted batch job 7507295
# Submitted batch job 7507296
# Submitted batch job 7507297
# Submitted batch job 7507298
# Submitted batch job 7507299
# Submitted batch job 7507300
# Submitted batch job 7507301
# Submitted batch job 7507302
# Submitted batch job 7507303
# Submitted batch job 7507304
# Submitted batch job 7507305
# Submitted batch job 7507306
# Submitted batch job 7507307
# Submitted batch job 7507308
# Submitted batch job 7507309
# Submitted batch job 7507310
# Submitted batch job 7507311
# Submitted batch job 7507312
# Submitted batch job 7507313
# CompletedProcess(args='sh ./run_dft.sh', returncode=0)
